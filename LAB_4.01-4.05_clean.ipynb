# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#4.01_lab_cleaning_numerical_data_solution.md" data-toc-modified-id="4.01_lab_cleaning_numerical_data_solution.md-0.1"><span class="toc-item-num">0.1&nbsp;&nbsp;</span>4.01_lab_cleaning_numerical_data_solution.md</a></span><ul class="toc-item"><li><span><a href="#For-this-lab,-we-will-be-using-the-dataset-in-the-Customer-Analysis-Business-Case.-This-dataset-can-be-found-in-files_for_lab-folder." data-toc-modified-id="For-this-lab,-we-will-be-using-the-dataset-in-the-Customer-Analysis-Business-Case.-This-dataset-can-be-found-in-files_for_lab-folder.-0.1.1"><span class="toc-item-num">0.1.1&nbsp;&nbsp;</span>For this lab, we will be using the dataset in the Customer Analysis Business Case. This dataset can be found in files_for_lab folder.</a></span></li><li><span><a href="#https://github.com/ironhack-labs/lab-cleaning-numerical-data" data-toc-modified-id="https://github.com/ironhack-labs/lab-cleaning-numerical-data-0.1.2"><span class="toc-item-num">0.1.2&nbsp;&nbsp;</span><a href="https://github.com/ironhack-labs/lab-cleaning-numerical-data" target="_blank">https://github.com/ironhack-labs/lab-cleaning-numerical-data</a></a></span></li><li><span><a href="#1.-Import-the-necessary-libraries." data-toc-modified-id="1.-Import-the-necessary-libraries.-0.1.3"><span class="toc-item-num">0.1.3&nbsp;&nbsp;</span>1. Import the necessary libraries.</a></span></li><li><span><a href="#2.-Load-the-we_fn_use_c_marketing_customer_value_analysis.csv-into-the-variable-customer_df." data-toc-modified-id="2.-Load-the-we_fn_use_c_marketing_customer_value_analysis.csv-into-the-variable-customer_df.-0.1.4"><span class="toc-item-num">0.1.4&nbsp;&nbsp;</span>2. Load the we_fn_use_c_marketing_customer_value_analysis.csv into the variable customer_df.</a></span></li><li><span><a href="#3.-First-look-at-its-main-features-(head,-shape,-info)." data-toc-modified-id="3.-First-look-at-its-main-features-(head,-shape,-info).-0.1.5"><span class="toc-item-num">0.1.5&nbsp;&nbsp;</span>3. First look at its main features (head, shape, info).</a></span></li><li><span><a href="#4.-Rename-the-columns-so-they-follow-the-PE8-(snake-case)." data-toc-modified-id="4.-Rename-the-columns-so-they-follow-the-PE8-(snake-case).-0.1.6"><span class="toc-item-num">0.1.6&nbsp;&nbsp;</span>4. Rename the columns so they follow the PE8 (snake case).</a></span></li><li><span><a href="#5.-Change-effective-to-date-column-to-datetime-format." data-toc-modified-id="5.-Change-effective-to-date-column-to-datetime-format.-0.1.7"><span class="toc-item-num">0.1.7&nbsp;&nbsp;</span>5. Change effective to date column to datetime format.</a></span></li><li><span><a href="#6.-Check-NaN-values-per-column." data-toc-modified-id="6.-Check-NaN-values-per-column.-0.1.8"><span class="toc-item-num">0.1.8&nbsp;&nbsp;</span>6. Check NaN values per column.</a></span></li><li><span><a href="#7.-Define-a-function-that-differentiates-between-continuous-and-discrete-variables." data-toc-modified-id="7.-Define-a-function-that-differentiates-between-continuous-and-discrete-variables.-0.1.9"><span class="toc-item-num">0.1.9&nbsp;&nbsp;</span>7. Define a function that differentiates between continuous and discrete variables.</a></span></li><li><span><a href="#8.-For-the-categorical-data,-check-if-there-is-some-kind-of-text-in-a-variable-so-we-would-need-to-clean-it." data-toc-modified-id="8.-For-the-categorical-data,-check-if-there-is-some-kind-of-text-in-a-variable-so-we-would-need-to-clean-it.-0.1.10"><span class="toc-item-num">0.1.10&nbsp;&nbsp;</span>8. For the categorical data, check if there is some kind of text in a variable so we would need to clean it.</a></span></li><li><span><a href="#9.-Get-categorical-features." data-toc-modified-id="9.-Get-categorical-features.-0.1.11"><span class="toc-item-num">0.1.11&nbsp;&nbsp;</span>9. Get categorical features.</a></span></li><li><span><a href="#10.-What-should-we-do-with-the-customer_id-column?" data-toc-modified-id="10.-What-should-we-do-with-the-customer_id-column?-0.1.12"><span class="toc-item-num">0.1.12&nbsp;&nbsp;</span>10. What should we do with the customer_id column?</a></span></li></ul></li></ul></li><li><span><a href="#Lab-4.02-|-Cleaning-categorical-data" data-toc-modified-id="Lab-4.02-|-Cleaning-categorical-data-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Lab 4.02 | Cleaning categorical data</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#For-this-lab,-we-will-be-using-the-dataset-in-the-Customer-Analysis-Business-Case.-This-dataset-can-be-found-in-files_for_lab-folder.-In-this-lab-we-will-explore-categorical-data." data-toc-modified-id="For-this-lab,-we-will-be-using-the-dataset-in-the-Customer-Analysis-Business-Case.-This-dataset-can-be-found-in-files_for_lab-folder.-In-this-lab-we-will-explore-categorical-data.-1.0.1"><span class="toc-item-num">1.0.1&nbsp;&nbsp;</span>For this lab, we will be using the dataset in the Customer Analysis Business Case. This dataset can be found in files_for_lab folder. In this lab we will explore categorical data.</a></span></li><li><span><a href="#1.-Import-the-necessary-libraries." data-toc-modified-id="1.-Import-the-necessary-libraries.-1.0.2"><span class="toc-item-num">1.0.2&nbsp;&nbsp;</span>1. Import the necessary libraries.</a></span></li><li><span><a href="#2.-Load-the-continuous-and-discrete-variables-into-continuous_df-and-discrete_df-variables." data-toc-modified-id="2.-Load-the-continuous-and-discrete-variables-into-continuous_df-and-discrete_df-variables.-1.0.3"><span class="toc-item-num">1.0.3&nbsp;&nbsp;</span>2. Load the continuous and discrete variables into continuous_df and discrete_df variables.</a></span></li><li><span><a href="#3.-Plot-a-correlation-matrix,-what-can-you-see?" data-toc-modified-id="3.-Plot-a-correlation-matrix,-what-can-you-see?-1.0.4"><span class="toc-item-num">1.0.4&nbsp;&nbsp;</span>3. Plot a correlation matrix, what can you see?</a></span></li><li><span><a href="#4.-Create-a-function-to-plot-every-discrete-variables.-Do-the-same-with-continuous-variables-(be-careful,-you-may-change-the-plot-type-to-another-one-better-suited-for-continuous-data)." data-toc-modified-id="4.-Create-a-function-to-plot-every-discrete-variables.-Do-the-same-with-continuous-variables-(be-careful,-you-may-change-the-plot-type-to-another-one-better-suited-for-continuous-data).-1.0.5"><span class="toc-item-num">1.0.5&nbsp;&nbsp;</span>4. Create a function to plot every discrete variables. Do the same with continuous variables (be careful, you may change the plot type to another one better suited for continuous data).</a></span></li><li><span><a href="#5.-What-can-you-see-in-the-plots?" data-toc-modified-id="5.-What-can-you-see-in-the-plots?-1.0.6"><span class="toc-item-num">1.0.6&nbsp;&nbsp;</span>5. What can you see in the plots?</a></span></li><li><span><a href="#6.-Look-for-outliers-in-the-continuous-variables-we-have-found.-Hint:-There-was-a-good-plot-to-do-that." data-toc-modified-id="6.-Look-for-outliers-in-the-continuous-variables-we-have-found.-Hint:-There-was-a-good-plot-to-do-that.-1.0.7"><span class="toc-item-num">1.0.7&nbsp;&nbsp;</span>6. Look for outliers in the continuous variables we have found. Hint: There was a good plot to do that.</a></span></li><li><span><a href="#7.-Have-you-found-outliers?-If-you-have,-what-should-we-do-with-them?" data-toc-modified-id="7.-Have-you-found-outliers?-If-you-have,-what-should-we-do-with-them?-1.0.8"><span class="toc-item-num">1.0.8&nbsp;&nbsp;</span>7. Have you found outliers? If you have, what should we do with them?</a></span></li><li><span><a href="#8.-Check-nan-values-per-column." data-toc-modified-id="8.-Check-nan-values-per-column.-1.0.9"><span class="toc-item-num">1.0.9&nbsp;&nbsp;</span>8. Check nan values per column.</a></span></li></ul></li></ul></li><li><span><a href="#Lab-4.03-|-Feature-extraction" data-toc-modified-id="Lab-4.03-|-Feature-extraction-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Lab 4.03 | Feature extraction</a></span><ul class="toc-item"><li><span><a href="#1.-Open-the-categoricals-variable-we-created-before." data-toc-modified-id="1.-Open-the-categoricals-variable-we-created-before.-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>1. Open the categoricals variable we created before.</a></span></li><li><span><a href="#2.-Plot-all-the-categorical-variables-with-the-proper-plot.-What-can-you-see?" data-toc-modified-id="2.-Plot-all-the-categorical-variables-with-the-proper-plot.-What-can-you-see?-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>2. Plot all the categorical variables with the proper plot. What can you see?</a></span></li><li><span><a href="#3.-There-might-be-some-columns-that-seem-to-be-redundant,-check-their-values-to-be-sure.-What-should-we-do-with-them?" data-toc-modified-id="3.-There-might-be-some-columns-that-seem-to-be-redundant,-check-their-values-to-be-sure.-What-should-we-do-with-them?-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>3. There might be some columns that seem to be redundant, check their values to be sure. What should we do with them?</a></span></li><li><span><a href="#4.-Plot-time-variable.-Can-you-extract-something-from-it?" data-toc-modified-id="4.-Plot-time-variable.-Can-you-extract-something-from-it?-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>4. Plot time variable. Can you extract something from it?</a></span></li></ul></li><li><span><a href="#Lab-4.04-|-Data-cleaning-and-wrangling" data-toc-modified-id="Lab-4.04-|-Data-cleaning-and-wrangling-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Lab 4.04 | Data cleaning and wrangling</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#1.-We-will-start-with-removing-outliers.-So-far,-we-have-discussed-different-methods-to-remove-outliers.-Use-the-one-you-feel-more-comfortable-with,-define-a-function-for-that.-Use-the-function-to-remove-the-outliers-and-apply-it-to-the-dataframe." data-toc-modified-id="1.-We-will-start-with-removing-outliers.-So-far,-we-have-discussed-different-methods-to-remove-outliers.-Use-the-one-you-feel-more-comfortable-with,-define-a-function-for-that.-Use-the-function-to-remove-the-outliers-and-apply-it-to-the-dataframe.-3.0.1"><span class="toc-item-num">3.0.1&nbsp;&nbsp;</span>1. We will start with removing outliers. So far, we have discussed different methods to remove outliers. Use the one you feel more comfortable with, define a function for that. Use the function to remove the outliers and apply it to the dataframe.</a></span></li><li><span><a href="#2.-Create-a-copy-of-the-dataframe-for-the-data-wrangling." data-toc-modified-id="2.-Create-a-copy-of-the-dataframe-for-the-data-wrangling.-3.0.2"><span class="toc-item-num">3.0.2&nbsp;&nbsp;</span>2. Create a copy of the dataframe for the data wrangling.</a></span></li><li><span><a href="#3.-Normalize-the-continuous-variables-(but-target).-You-can-use-any-one-method-you-want." data-toc-modified-id="3.-Normalize-the-continuous-variables-(but-target).-You-can-use-any-one-method-you-want.-3.0.3"><span class="toc-item-num">3.0.3&nbsp;&nbsp;</span>3. Normalize the continuous variables (but target). You can use any one method you want.</a></span></li><li><span><a href="#4.-Encode-the-categorical-variables" data-toc-modified-id="4.-Encode-the-categorical-variables-3.0.4"><span class="toc-item-num">3.0.4&nbsp;&nbsp;</span>4. Encode the categorical variables</a></span></li><li><span><a href="#5.-The-time-variable-can-be-useful.-Try-to-transform-its-data-into-a-useful-one.-Hint:-Day-week-and-month-as-integers-might-be-useful." data-toc-modified-id="5.-The-time-variable-can-be-useful.-Try-to-transform-its-data-into-a-useful-one.-Hint:-Day-week-and-month-as-integers-might-be-useful.-3.0.5"><span class="toc-item-num">3.0.5&nbsp;&nbsp;</span>5. The time variable can be useful. Try to transform its data into a useful one. Hint: Day week and month as integers might be useful.</a></span></li><li><span><a href="#6.-Since-the-model-will-only-accept-numerical-data,-check-and-make-sure-that-every-column-is-numerical,-if-some-are-not,-change-it-using-encoding." data-toc-modified-id="6.-Since-the-model-will-only-accept-numerical-data,-check-and-make-sure-that-every-column-is-numerical,-if-some-are-not,-change-it-using-encoding.-3.0.6"><span class="toc-item-num">3.0.6&nbsp;&nbsp;</span>6. Since the model will only accept numerical data, check and make sure that every column is numerical, if some are not, change it using encoding.</a></span></li><li><span><a href="#Ordinal-encoders" data-toc-modified-id="Ordinal-encoders-3.0.7"><span class="toc-item-num">3.0.7&nbsp;&nbsp;</span>Ordinal encoders</a></span></li></ul></li><li><span><a href="#One-Hot-Encoding" data-toc-modified-id="One-Hot-Encoding-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>One Hot Encoding</a></span></li></ul></li><li><span><a href="#4.05-Lab-|-Comparing-regression-models" data-toc-modified-id="4.05-Lab-|-Comparing-regression-models-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>4.05 Lab | Comparing regression models</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#1.-In-this-final-lab,-we-will-model-our-data.-Import-sklearn-train_test_split-and-separate-the-data." data-toc-modified-id="1.-In-this-final-lab,-we-will-model-our-data.-Import-sklearn-train_test_split-and-separate-the-data.-4.0.1"><span class="toc-item-num">4.0.1&nbsp;&nbsp;</span>1. In this final lab, we will model our data. Import sklearn train_test_split and separate the data.</a></span></li><li><span><a href="#2.-Try-a-simple-linear-regression-with-all-the-data-to-see-whether-we-are-getting-good-results." data-toc-modified-id="2.-Try-a-simple-linear-regression-with-all-the-data-to-see-whether-we-are-getting-good-results.-4.0.2"><span class="toc-item-num">4.0.2&nbsp;&nbsp;</span>2. Try a simple linear regression with all the data to see whether we are getting good results.</a></span></li><li><span><a href="#3.-Great!-Now-define-a-function-that-takes-a-list-of-models-and-train-(and-tests)-them-so-we-can-try-a-lot-of-them-without-repeating-code." data-toc-modified-id="3.-Great!-Now-define-a-function-that-takes-a-list-of-models-and-train-(and-tests)-them-so-we-can-try-a-lot-of-them-without-repeating-code.-4.0.3"><span class="toc-item-num">4.0.3&nbsp;&nbsp;</span>3. Great! Now define a function that takes a list of models and train (and tests) them so we can try a lot of them without repeating code.</a></span></li><li><span><a href="#4.-Use-the-function-to-check-LinearRegressor-and-KNeighborsRegressor." data-toc-modified-id="4.-Use-the-function-to-check-LinearRegressor-and-KNeighborsRegressor.-4.0.4"><span class="toc-item-num">4.0.4&nbsp;&nbsp;</span>4. Use the function to check LinearRegressor and KNeighborsRegressor.</a></span></li><li><span><a href="#5.-You-can-check-also-the-MLPRegressor-for-this-task!" data-toc-modified-id="5.-You-can-check-also-the-MLPRegressor-for-this-task!-4.0.5"><span class="toc-item-num">4.0.5&nbsp;&nbsp;</span>5. You can check also the MLPRegressor for this task!</a></span></li><li><span><a href="#6.-Check-and-discuss-the-results." data-toc-modified-id="6.-Check-and-discuss-the-results.-4.0.6"><span class="toc-item-num">4.0.6&nbsp;&nbsp;</span>6. Check and discuss the results.</a></span></li></ul></li></ul></li><li><span><a href="#4.05-Lab-|-Random-variable-distributions" data-toc-modified-id="4.05-Lab-|-Random-variable-distributions-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>4.05 Lab | Random variable distributions</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#1.-Get-the-numerical-variables-from-our-dataset." data-toc-modified-id="1.-Get-the-numerical-variables-from-our-dataset.-5.0.1"><span class="toc-item-num">5.0.1&nbsp;&nbsp;</span>1. Get the numerical variables from our dataset.</a></span></li><li><span><a href="#2.-Check-using-a-distribution-plot-if-the-variables-fit-the-theoretical-normal-or-exponential-distribution." data-toc-modified-id="2.-Check-using-a-distribution-plot-if-the-variables-fit-the-theoretical-normal-or-exponential-distribution.-5.0.2"><span class="toc-item-num">5.0.2&nbsp;&nbsp;</span>2. Check using a distribution plot if the variables fit the theoretical normal or exponential distribution.</a></span></li><li><span><a href="#1.-Check-if-any-of-the-transformations-(log-transform,-etc.)-we-have-seen-up-to-this-point-changes-the-result." data-toc-modified-id="1.-Check-if-any-of-the-transformations-(log-transform,-etc.)-we-have-seen-up-to-this-point-changes-the-result.-5.0.3"><span class="toc-item-num">5.0.3&nbsp;&nbsp;</span>1. Check if any of the transformations (log-transform, etc.) we have seen up to this point changes the result.</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# ## 4.01_lab_cleaning_numerical_data_solution.md
#
# ### For this lab, we will be using the dataset in the Customer Analysis Business Case. This dataset can be found in files_for_lab folder.
#
# ### https://github.com/ironhack-labs/lab-cleaning-numerical-data

# %% [markdown]
# ### 1. Import the necessary libraries.

# %%
import pandas as pd
import numpy as np
import datetime
import warnings
warnings.filterwarnings('ignore')
warnings.filterwarnings("ignore", message="numpy.ufunc size changed")
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
pd.set_option('display.max_columns', None)
import re

# %%
from sklearn.linear_model import LinearRegression, Lasso, Ridge, ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.neural_network import MLPRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor

# %% [markdown]
# ### 2. Load the we_fn_use_c_marketing_customer_value_analysis.csv into the variable customer_df.

# %%
customer_df = pd.read_csv("we_fn_use_c_marketing_customer_value_analysis.csv")

# %% [markdown]
# ### 3. First look at its main features (head, shape, info).

# %%
customer_df.head()
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income Location Code  \
# 0           2/24/11         Employed      F   56274      Suburban
# 1           1/31/11       Unemployed      F       0      Suburban
# 2           2/19/11         Employed      F   48767      Suburban
# 3           1/20/11       Unemployed      M       0      Suburban
# 4            2/3/11         Employed      M   43836         Rural
#
#   Marital Status  Monthly Premium Auto  Months Since Last Claim  \
# ...

# %%
customer_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9134 entries, 0 to 9133
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Customer                       9134 non-null   object
#  1   State                          9134 non-null   object
#  2   Customer Lifetime Value        9134 non-null   float64
#  3   Response                       9134 non-null   object
#  4   Coverage                       9134 non-null   object
#  5   Education                      9134 non-null   object
#  6   Effective To Date              9134 non-null   object
#  7   EmploymentStatus               9134 non-null   object
#  8   Gender                         9134 non-null   object
#  9   Income                         9134 non-null   int64
#  10  Location Code                  9134 non-null   object
#  11  Marital Status                 9134 non-null   object
# ...

# %%
customer_df.shape
# Out:
# (9134, 24)

# %% [markdown]
# ### 4. Rename the columns so they follow the PE8 (snake case).

# %%
customer_df.columns = [col.replace(" ", "_").lower() for col in customer_df]

# %%
customer_df.columns
# Out:
# Index(['customer', 'state', 'customer_lifetime_value', 'response', 'coverage',
#        'education', 'effective_to_date', 'employmentstatus', 'gender',
#        'income', 'location_code', 'marital_status', 'monthly_premium_auto',
#        'months_since_last_claim', 'months_since_policy_inception',
#        'number_of_open_complaints', 'number_of_policies', 'policy_type',
#        'policy', 'renew_offer_type', 'sales_channel', 'total_claim_amount',
#        'vehicle_class', 'vehicle_size'],
#       dtype='object')

# %% [markdown]
# ### 5. Change effective to date column to datetime format.

# %%
customer_df['effective_to_date'] = pd.to_datetime(customer_df['effective_to_date'])

# %% [markdown]
# ### 6. Check NaN values per column.

# %%
customer_df.isna().sum()/len(customer_df)
# Out:
# customer                         0.0
# state                            0.0
# customer_lifetime_value          0.0
# response                         0.0
# coverage                         0.0
# education                        0.0
# effective_to_date                0.0
# employmentstatus                 0.0
# gender                           0.0
# income                           0.0
# location_code                    0.0
# marital_status                   0.0
# monthly_premium_auto             0.0
# months_since_last_claim          0.0
# months_since_policy_inception    0.0
# number_of_open_complaints        0.0
# number_of_policies               0.0
# policy_type                      0.0
# policy                           0.0
# renew_offer_type                 0.0
# sales_channel                    0.0
# total_claim_amount               0.0
# vehicle_class                    0.0
# vehicle_size                     0.0
# dtype: float64

# %% [markdown]
# ### 7. Define a function that differentiates between continuous and discrete variables.
# Hint: A number of unique values might be useful. Store continuous data into a continuous variable and do the same for discrete and categorical.

# %%
numericals = customer_df.select_dtypes(np.number)
numericals.head()
# Out:
#    customer_lifetime_value  income  monthly_premium_auto  \
# 0              2763.519279   56274                    69
# 1              6979.535903       0                    94
# 2             12887.431650   48767                   108
# 3              7645.861827       0                   106
# 4              2813.692575   43836                    73
#
#    months_since_last_claim  months_since_policy_inception  \
# 0                       32                              5
# 1                       13                             42
# 2                       18                             38
# 3                       18                             65
# 4                       12                             44
#
#    number_of_open_complaints  number_of_policies  total_claim_amount
# 0                          0                   1          384.811147
# 1                          0                   8         1131.464935
# ...

# %%
discrete = [i for i in numericals if (numericals[i].all() == numericals[i].apply(int).all()) \
                 & (len(numericals[i].unique()) < (numericals.shape[0] * 0.01))]

# %%
continuous = list(numericals.drop(columns = discrete).columns)

# %%
print(discrete)
# Out:
# ['months_since_last_claim', 'number_of_open_complaints', 'number_of_policies']

# %%
print(continuous)
# Out:
# ['customer_lifetime_value', 'income', 'monthly_premium_auto', 'months_since_policy_inception', 'total_claim_amount']

# %% [markdown]
# ### 8. For the categorical data, check if there is some kind of text in a variable so we would need to clean it.
# Hint: Use the same method you used in step 7. Depending on the implementation, decide what to do with the variables you get.

# %%
# the categorical values that are not text or IDs

# %%
# we will declare categorical variables with few unique
# as just categorical. if we found some with a lot of 
# unique values we would call them text.

categorical = customer_df.select_dtypes(object)

# %%
categorical_columns = [i for i in categorical if (len(categorical[i].unique()) < (numericals.shape[0] * 0.01))]

# %% [markdown]
# ### 9. Get categorical features.

# %%
# Check misspelling errors
for i in categorical[categorical_columns]:
    if (categorical[i].value_counts() < categorical.shape[0] * 0.01).any():
        print(i,":", categorical[i].value_counts()[categorical[i].value_counts() < categorical.shape[0] * 0.01])
# Out:
# policy : Special L1    66
# Name: policy, dtype: int64

# %% [markdown]
# ### 10. What should we do with the customer_id column?

# %%
categorical
# Out:
#      customer       state response  coverage education employmentstatus  \
# 0     BU79786  Washington       No     Basic  Bachelor         Employed
# 1     QZ44356     Arizona       No  Extended  Bachelor       Unemployed
# 2     AI49188      Nevada       No   Premium  Bachelor         Employed
# 3     WW63253  California       No     Basic  Bachelor       Unemployed
# 4     HB64268  Washington       No     Basic  Bachelor         Employed
# ...       ...         ...      ...       ...       ...              ...
# 9129  LA72316  California       No     Basic  Bachelor         Employed
# 9130  PK87824  California      Yes  Extended   College         Employed
# 9131  TD14365  California       No  Extended  Bachelor       Unemployed
# 9132  UP19263  California       No  Extended   College         Employed
# 9133  Y167826  California       No  Extended   College       Unemployed
#
#      gender location_code marital_status     policy_type        policy  \
# ...

# %%
# the customer column can be dropped
categorical_df = categorical.drop(columns = "customer")

# %% [markdown]
# # Lab 4.02 | Cleaning categorical data
# ### For this lab, we will be using the dataset in the Customer Analysis Business Case. This dataset can be found in files_for_lab folder. In this lab we will explore categorical data.

# %% [markdown]
# ### 1. Import the necessary libraries.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### 2. Load the continuous and discrete variables into continuous_df and discrete_df variables.

# %%
continuous_df = numericals.drop(columns = discrete)

# %%
discrete_df = numericals[discrete]

# %%
continuous_df.head(5)
# Out:
#    customer_lifetime_value  income  monthly_premium_auto  \
# 0              2763.519279   56274                    69
# 1              6979.535903       0                    94
# 2             12887.431650   48767                   108
# 3              7645.861827       0                   106
# 4              2813.692575   43836                    73
#
#    months_since_policy_inception  total_claim_amount
# 0                              5          384.811147
# 1                             42         1131.464935
# 2                             38          566.472247
# 3                             65          529.881344
# 4                             44          138.130879

# %%
discrete_df.head(5)
# Out:
#    months_since_last_claim  number_of_open_complaints  number_of_policies
# 0                       32                          0                   1
# 1                       13                          0                   8
# 2                       18                          0                   2
# 3                       18                          0                   7
# 4                       12                          0                   1

# %% [markdown]
# ### 3. Plot a correlation matrix, what can you see?

# %%
mask = np.zeros_like(numericals.corr())
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
    f, ax = plt.subplots(figsize=(16, 10))
    ax = sns.heatmap(numericals.corr(), mask=mask,
                     square=True, linewidths=1, cmap="coolwarm",
                     vmax = 0.8, vmin = -0.8)

# %% [markdown]
# ### 4. Create a function to plot every discrete variables. Do the same with continuous variables (be careful, you may change the plot type to another one better suited for continuous data).

# %%
# Visualization
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.colors import BASE_COLORS

# %%
def df_bar(df):
    """
    Docs
    """
    sns.set(rc={'figure.figsize':(16,8)})

    for i, col in enumerate(df):
        plt.figure(i)
        sns.barplot(x = df[col].value_counts().index, y = df[col].value_counts())

    plt.show()

# %%
df_bar(discrete_df)

# %%
def df_hist(df):
    """
    docs
    """
    sns.set(rc={'figure.figsize':(16,8)})
    for i, col in enumerate(df):
        plt.figure(i)
        sns.distplot(df[col], color = list(BASE_COLORS.keys())[i])
        plt.show()

# %%
df_hist(continuous_df)

# %% [markdown]
# ### 5. What can you see in the plots?

# %% [markdown]
# ### 6. Look for outliers in the continuous variables we have found. Hint: There was a good plot to do that.

# %%
box_colors = ["blue", "yellow", "red"]

f, ax = plt.subplots(1, 3, figsize=(16,8))

for i, col in enumerate(continuous[:3]):
    sns.boxplot(data = continuous_df[col], ax = ax[i], color = box_colors[i])
    ax[i].set_title(col, fontsize = 14)

plt.show()

# %%
# outliers in customer_lifetime and premium auto

# %% [markdown]
# ### 7. Have you found outliers? If you have, what should we do with them?

# %%
# outliers in customer_lifetime and premium auto

# %% [markdown]
# ### 8. Check nan values per column.

# %%
# done this already

# %% [markdown]
# # Lab 4.03 | Feature extraction
# For this lab, we will be using the same dataset we used in the previous labs. We recommend using the same notebook since you will be reusing the same variables you previous created and used in labs.

# %% [markdown]
# ## 1. Open the categoricals variable we created before.

# %% [markdown]
# ## 2. Plot all the categorical variables with the proper plot. What can you see?

# %% [markdown]
# ## 3. There might be some columns that seem to be redundant, check their values to be sure. What should we do with them?

# %% [markdown]
# ## 4. Plot time variable. Can you extract something from it?

# %% [markdown]
# # Lab 4.04 | Data cleaning and wrangling
# So far we have worked on EDA. This lab will focus on data cleaning and wrangling from everything we noticed before.
# Hint for Categorical Variables:
# You should deal with the categorical variables as shown below (for ordinal encoding, dummy code has been provided as well):
# - One hot to state
# - Ordinal to coverage
# - Ordinal to employmentstatus
# - Ordinal to location code
# - One hot to marital status
# - One hot to policy type
# - One hot to policy
# - One hot to renew offercustomer_df
# - One hot to sales channel
# - One hot vehicle class
# - Ordinal vehicle size
#
# data["coverage"] = data["coverage"].map({"Basic" : 0, "Extended" : 1, "Premium" : 2})
# given that column "coverage" in the dataframe "data" has three categories:
# "basic", "extended", and "premium" and values are to be represented in the same order.

# %% [markdown]
# ### 1. We will start with removing outliers. So far, we have discussed different methods to remove outliers. Use the one you feel more comfortable with, define a function for that. Use the function to remove the outliers and apply it to the dataframe.

# %%
# explore hist, boxplot with jitter

# %%
# No NaNs so just remove outliers (normalization method)
def outliers(column, threshold = 3):
    """
    docs
    """
    
    data = column[abs(column.apply(lambda x: (x - column.mean()) / column.var() ** (1/2))) > threshold]
    return data

# %%
CLV_outliers = outliers(customer_df["customer_lifetime_value"])
MPA_outliers = outliers(customer_df["monthly_premium_auto"])

# %%
to_drop = CLV_outliers.index | MPA_outliers.index # Union

# %%
clean_customer_df = customer_df.drop(to_drop).reset_index(drop = True)
clean_customer_df
# Out:
#      customer       state  customer_lifetime_value response  coverage  \
# 0     BU79786  Washington              2763.519279       No     Basic
# 1     QZ44356     Arizona              6979.535903       No  Extended
# 2     AI49188      Nevada             12887.431650       No   Premium
# 3     WW63253  California              7645.861827       No     Basic
# 4     HB64268  Washington              2813.692575       No     Basic
# ...       ...         ...                      ...      ...       ...
# 8748  LA72316  California             23405.987980       No     Basic
# 8749  PK87824  California              3096.511217      Yes  Extended
# 8750  TD14365  California              8163.890428       No  Extended
# 8751  UP19263  California              7524.442436       No  Extended
# 8752  Y167826  California              2611.836866       No  Extended
#
#      education effective_to_date employmentstatus gender  income  \
# ...

# %%
###################################################

# %%
# Much better
clean_customer_df["customer_lifetime_value"].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 2. Create a copy of the dataframe for the data wrangling.

# %%
# Create copy
df_copy = clean_customer_df.copy()

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8753 entries, 0 to 8752
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   customer                       8753 non-null   object
#  1   state                          8753 non-null   object
#  2   customer_lifetime_value        8753 non-null   float64
#  3   response                       8753 non-null   object
#  4   coverage                       8753 non-null   object
#  5   education                      8753 non-null   object
#  6   effective_to_date              8753 non-null   datetime64[ns]
#  7   employmentstatus               8753 non-null   object
#  8   gender                         8753 non-null   object
#  9   income                         8753 non-null   int64
#  10  location_code                  8753 non-null   object
#  11  marital_status                 8753 non-null   object
# ...

# %% [markdown]
# ### 3. Normalize the continuous variables (but target). You can use any one method you want.

# %%
# numeric (8columns/8753rows) check if they are continous

# %%
continuous
# Out:
# ['customer_lifetime_value',
#  'income',
#  'monthly_premium_auto',
#  'months_since_policy_inception',
#  'total_claim_amount']

# %%
# normalising continuous variables (but target)
continuous.remove("months_since_policy_inception")
continuous.remove("total_claim_amount")

# %%
for cont_var in continuous:
    maximum = clean_customer_df[cont_var].max()
    minimum = clean_customer_df[cont_var].min()
    clean_customer_df[cont_var] = clean_customer_df[cont_var].apply(lambda x: (x - minimum) / (maximum - minimum))

# %%
clean_customer_df[continuous].head()
# Out:
#    customer_lifetime_value    income  monthly_premium_auto
# 0                 0.032522  0.562847              0.059259
# 1                 0.190941  0.000000              0.244444
# 2                 0.412934  0.487763              0.348148
# 3                 0.215979  0.000000              0.333333
# 4                 0.034407  0.438443              0.088889

# %% [markdown]
# ### 4. Encode the categorical variables

# %%
# One hot to state
# Ordinal to coverage
# Ordinal to employmentstatus
# Ordinal to location code
# One hot to marital status
# One hot to policy type
# One hot to policy
# One hot to renew offercustomer_df
# One hot to sales channel
# One hot vehicle class
# Ordinal vehicle size

# %%
# Response to bool 
clean_customer_df["response"] = clean_customer_df["response"].apply(lambda x: 1 if x == "Yes" else 0)

# %%
clean_customer_df["education"] = clean_customer_df["education"].apply(lambda x: "Graduate" if x in ["Master", "Doctor"] else x)

# %%
inactive = ["Medical Leave", "Disabled", "Retired"]
clean_customer_df["employmentstatus"] = clean_customer_df["employmentstatus"].apply(lambda x: "Inactive" if x in inactive else x)

# %%
clean_customer_df["gender"] = clean_customer_df["gender"].apply(lambda x: 1 if x == "F" else 0)

# %%
clean_customer_df["policy"] = clean_customer_df["policy"].apply(lambda x: x[-2:])

# %%
luxury = ["Sports Car", "Luxury SUV", "Luxury Car"]
clean_customer_df["vehicle_class"] = clean_customer_df["vehicle_class"].apply(lambda x: "Luxury" if x in luxury else x)

# %% [markdown]
# ### 5. The time variable can be useful. Try to transform its data into a useful one. Hint: Day week and month as integers might be useful.

# %%
# done above

# %% [markdown]
# ### 6. Since the model will only accept numerical data, check and make sure that every column is numerical, if some are not, change it using encoding.

# %%
final_df = clean_customer_df.copy()

# %%
# Drop customer (id)
ordinal = clean_customer_df.drop(columns = "customer")
ordinal
# Out:
#            state  customer_lifetime_value  response  coverage education  \
# 0     Washington                 0.032522         0     Basic  Bachelor
# 1        Arizona                 0.190941         0  Extended  Bachelor
# 2         Nevada                 0.412934         0   Premium  Bachelor
# 3     California                 0.215979         0     Basic  Bachelor
# 4     Washington                 0.034407         0     Basic  Bachelor
# ...          ...                      ...       ...       ...       ...
# 8748  California                 0.808175         0     Basic  Bachelor
# 8749  California                 0.045034         1  Extended   College
# 8750  California                 0.235444         0  Extended  Bachelor
# 8751  California                 0.211417         0  Extended   College
# 8752  California                 0.026823         0  Extended   College
#
#      effective_to_date employmentstatus  gender    income location_code  \
# ...

# %% [markdown]
# ### Ordinal encoders

# %%
# Ordinal to coverage
ordinal["coverage"] = ordinal["coverage"].map({"Basic" : 0, "Extended" : 1, "Premium" : 2})

# %%
# Ordinal to employmentstatus
ordinal["employmentstatus"] = ordinal["employmentstatus"].map({"Unemployed" : 0, "Inactive" : 1, "Employed" : 2})

# %%
# Ordinal to location code
ordinal["location_code"] = ordinal["location_code"].map({"Rural" : 0, "Suburban" : 1, "Urban" : 2})

# %%
# Ordinal vehicle size
ordinal["vehicle_size"] = ordinal["vehicle_size"].map({"Small" : 0, "Medsize" : 1, "Large" : 2})

# %%
ordinal.info() # Types changed
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8753 entries, 0 to 8752
# Data columns (total 23 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   state                          8753 non-null   object
#  1   customer_lifetime_value        8753 non-null   float64
#  2   response                       8753 non-null   int64
#  3   coverage                       8753 non-null   int64
#  4   education                      8753 non-null   object
#  5   effective_to_date              8753 non-null   datetime64[ns]
#  6   employmentstatus               8753 non-null   int64
#  7   gender                         8753 non-null   int64
#  8   income                         8753 non-null   float64
#  9   location_code                  8753 non-null   int64
#  10  marital_status                 8753 non-null   object
#  11  monthly_premium_auto           8753 non-null   float64
# ...

# %% [markdown]
# ## One Hot Encoding

# %%
one_hot = ordinal.copy()

# %%
one_hot_colums = final_df.select_dtypes(include = object).columns[1:]
one_hot_colums
# Out:
# Index(['state', 'coverage', 'education', 'employmentstatus', 'location_code',
#        'marital_status', 'policy_type', 'policy', 'renew_offer_type',
#        'sales_channel', 'vehicle_class', 'vehicle_size'],
#       dtype='object')

# %%
# One hot encoders

# One hot to state
# One hot to marital status
# One hot to policy type
# One hot to policy
# One hot to renew offercustomer_df
# One hot to sales channel
# One hot vehicle class

# %%
one_hot = pd.get_dummies(one_hot, columns = one_hot_colums)
one_hot
# Out:
#       customer_lifetime_value  response effective_to_date  gender    income  \
# 0                    0.032522         0        2011-02-24       1  0.562847
# 1                    0.190941         0        2011-01-31       1  0.000000
# 2                    0.412934         0        2011-02-19       1  0.487763
# 3                    0.215979         0        2011-01-20       0  0.000000
# 4                    0.034407         0        2011-02-03       0  0.438443
# ...                       ...       ...               ...     ...       ...
# 8748                 0.808175         0        2011-02-10       0  0.719547
# 8749                 0.045034         1        2011-02-12       1  0.216081
# 8750                 0.235444         0        2011-02-06       0  0.000000
# 8751                 0.211417         0        2011-02-03       0  0.219452
# 8752                 0.026823         0        2011-02-14       0  0.000000
#
#       monthly_premium_auto  months_since_last_claim  \
# ...

# %% [markdown]
# # 4.05 Lab | Comparing regression models
# For this lab, we will be using the same dataset we used in the previous labs. We recommend using the same notebook since you will be reusing the same variables you previous created and used in labs.

# %% [markdown]
# ### 1. In this final lab, we will model our data. Import sklearn train_test_split and separate the data.

# %% [markdown]
# ### 2. Try a simple linear regression with all the data to see whether we are getting good results.

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
X_train, X_test, y_train, y_test = train_test_split(final_df.drop(columns = "total_claim_amount"),
                                                    final_df.total_claim_amount, test_size = 0.2)

# %%
def models_automation(models, X_train, y_train):
    for model in models:
        model.fit(X_train, y_train)
        print(f"{model.__class__.__name__}: Train -> {model.score(X_train, y_train)}, Test -> {model.score(X_test, y_test)}")

linear_models = [LinearRegression(), Lasso(), Ridge(), ElasticNet()]
models_automation(linear_models, X_train, y_train)

# %% [markdown]
# ### 3. Great! Now define a function that takes a list of models and train (and tests) them so we can try a lot of them without repeating code.

# %%
from sklearn.svm import SVR
svr = [SVR()]
models_automation(svr, X_train, y_train)

# %% [markdown]
# ### 4. Use the function to check LinearRegressor and KNeighborsRegressor.

# %%
from sklearn.neighbors import KNeighborsRegressor
knn = [KNeighborsRegressor()]
models_automation(knn, X_train, y_train)

# %%
from sklearn.tree import DecisionTreeRegressor
dtr = [DecisionTreeRegressor()]
models_automation(dtr, X_train, y_train)

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor
rfr = [GradientBoostingRegressor(), RandomForestRegressor()]
models_automation(rfr, X_train, y_train)

# %% [markdown]
# ### 5. You can check also the MLPRegressor for this task!

# %%
from sklearn.neural_network import MLPRegressor
mlpr = [MLPRegressor(max_iter = 1000)]
models_automation(mlpr, X_train, y_train)

# %% [markdown]
# ### 6. Check and discuss the results.

# %% [markdown]
# # 4.05 Lab | Random variable distributions
# Refer to the files_for_lab/we_fn_use_c_marketing_customer_value_analysis.csv dataset.

# %% [markdown]
# ### 1. Get the numerical variables from our dataset.

# %%
data = pd.read_csv("we_fn_use_c_marketing_customer_value_analysis.csv")
data.head()
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income Location Code  \
# 0           2/24/11         Employed      F   56274      Suburban
# 1           1/31/11       Unemployed      F       0      Suburban
# 2           2/19/11         Employed      F   48767      Suburban
# 3           1/20/11       Unemployed      M       0      Suburban
# 4            2/3/11         Employed      M   43836         Rural
#
#   Marital Status  Monthly Premium Auto  Months Since Last Claim  \
# ...

# %%
numericals = data.select_dtypes(np.number)

# %%
list(numericals)
# Out:
# ['Customer Lifetime Value',
#  'Income',
#  'Monthly Premium Auto',
#  'Months Since Last Claim',
#  'Months Since Policy Inception',
#  'Number of Open Complaints',
#  'Number of Policies',
#  'Total Claim Amount']

# %% [markdown]
# ### 2. Check using a distribution plot if the variables fit the theoretical normal or exponential distribution.

# %% [markdown]
# ### 1. Check if any of the transformations (log-transform, etc.) we have seen up to this point changes the result.
